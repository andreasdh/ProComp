# %% [markdown]
# # How to build the notebooks
#
# Here's an overview of extra graphical and structural elements which can be generated through Myst Markdown to use in Jupyterbooks.

# %% [markdown]
# ## Boxes
#
# ```{admonition} Learning goals
# :class: note
# Used for learning goals.
# ```
#
# ```{admonition} Excercises
# :class: hint
# Used for excercises.
# ```
#
# ```{admonition} Remember
# :class: caution
# Used for highlighting important stuff.
# ```
#
# ```{admonition} Learning goals
# :class: danger
# Generally not used.
# ```
#
# ```{admonition} Error
# :class: error
# Generally not used.
# ```

# %% [markdown]
# This was created by the following code in Markdown:
# ````
# ```{admonition} Learning goals
# :class: note
# Used for learning goals.
# ```
#
# ```{admonition} Excercises
# :class: hint
# Used for excercises.
# ```
#
# ```{admonition} Remember
# :class: caution
# Used for highlighting important stuff.
# ```
#
# ```{admonition} Warning
# :class: danger
# Generally not used.
# ```
#
# ```{admonition} Error
# :class: error
# Generally not used.
# ```
# ````

# %% [markdown]
# ## Panels
# ````{panels}
# Content of the left panel.
#
# [![Jupyter Book Badge](https://jupyterbook.org/badge.svg)](https://img.shields.io/badge/Programming-Computational%20thinking-red)
#
# ---
#
# Panel header 2
# ^^^
# Panel body 2
# +++
# Panel footer 2
#
# ````

# %% [markdown]
# Panels can be made with the following code. In the first panel we also have a random badge generated through [shields.io](shields.io).
# - The panels are separated with ---
# - The first header is marked with ^^^
# - The second header is maked with +++
#
# `````
# ````{panels}
# Content of the left panel.
#
# [![Jupyter Book Badge](https://jupyterbook.org/badge.svg)](https://img.shields.io/badge/Programming-Computational%20thinking-red)
#
# ---
#
# Panel header 2
# ^^^
# Panel body 2
# +++
# Panel footer 2
# ```
# ````
# `````

# %% [markdown]
# We can also specify the number of colomns and the format of the borders:

# %% [markdown]
# ````{panels}
# :column: col-4
# :card: border-2
# Header A
# ^^^
# Body A
# ---
# Header B
# ^^^
# Body B
# ---
# Header C
# ^^^
# Body C
# ````

# %% [markdown]
# Which is generated with the following code:
# `````
# ````{panels}
# :column: col-4
# :card: border-2
# Header A
# ^^^
# Body A
# ---
# Header B
# ^^^
# Body B
# ---
# Header C
# ^^^
# Body C
# ````
# `````

# %% [markdown]
# ## Dropdowns
#
# ```{tip} Hint!
# :class: dropdown
# This is mainly used for extra information and hints.
# ```

# %% [markdown]
# Dropdown menus are created by adding the class _dropdown_ to an admonition (box):
#
# ````
# ```{tip} Hint!
# :class: dropdown
# This is mainly used for extra information and hints.
# ```
# ````

# %% [markdown]
# ## Tabs
# We can create tabs with text and/or coding blocks to separate content, like disciplinary specific such as physics examples, chemistry examples, life science examples and so on.
#
# ````{tabbed} c++
# Here's how it's done in C++
# ```{code-block} c++
#
# int main(const int argc, const char **argv) {
#   return 0;
# }
# ```
# ````
#
# ````{tabbed} python
# Here's how it's done in Python
# ```{code-block} python
#
# def main():
#     return
# ```
# ````
#
# ````{tabbed} java
# Here's how it's done in Java
# ```{code-block} java
#
# class Main {
#     public static void main(String[] args) {
#     }
# }
# ```
# ````
#
# ````{tabbed} julia
# Here's how it's done in Julia
# ```{code-block} julia
#
# function main()
# end
# ```
# ````
#
# ````{tabbed} fortran
# Here's how it's done in Fortran
# ```{code-block} fortran
#
# PROGRAM main
# END PROGRAM main
# ```
# ````

# %% [markdown]
# These tabs are generated with the following code:
#
# ````{tabbed} c++
# Here's how it's done in C++
# ```{code-block} c++
#
# int main(const int argc, const char **argv) {
#   return 0;
# }
# ```
# ````
#
# ````{tabbed} python
# Here's how it's done in Python
# ```{code-block} python
#
# def main():
#     return
# ```
# ````
#
# ````{tabbed} java
# Here's how it's done in Java
# ```{code-block} java
#
# class Main {
#     public static void main(String[] args) {
#     }
# }
# ```
# ````
#
# ````{tabbed} julia
# Here's how it's done in Julia
# ```{code-block} julia
#
# function main()
# end
# ```
# ````
#
# ````{tabbed} fortran
# Here's how it's done in Fortran
# ```{code-block} fortran
#
# PROGRAM main
# END PROGRAM main
# ```
# ````

# %% [markdown]
# ## Definition lists
# :     for i in range(10):
#
#
# :     for i in range(10):
#           a = a + 1

# %% [markdown]
# ## Figures
# You can insert figures like this:
# ````
# ```{figure} ./path/to/figure.jpg
# :name: label
#
# caption
# ```
# ````

# %% [markdown]
# ## Quotes
# One can also make nicely formatted quotes:
#
# ```{epigraph}
# All quotes are quotable.
#
# -- Andreas Haraldsrud, 2021
# ```
#
# which is made with the following code:
# ````
# ```{epigraph}
# All quotes are quotable.
#
# -- Andreas Haraldsrud, 2021
# ```
# ````
